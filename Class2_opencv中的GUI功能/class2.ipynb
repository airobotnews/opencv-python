# %% [markdown]
# ## 读取显示图片

# %%
import cv2 as cv
import sys
img=cv.imread(cv.samples.findFile("starry_night.jpg"))

if img is None:
    sys.exit("Could not read the image.")

cv.imshow("Display window",img)
k=cv.waitKey(0)

if k== ord("s"):
    cv.imwrite("starry_night.png",img)

# %% [markdown]
# ## 从摄像头获取图片

# %%
import unmpy as np
import cv2 as cv

cap=cv.VideoCapture(0)
if not cap.isOpend():
    print("Can not open camera")
    exit()

while True:
    ret,frame=cap.read()
    if not ret:
        print("Can't recevie frame (stream end?). Exiting...")
        break
    gray=cv.cvtColor(frame,cv_COLOR_BGR2GRAY)
    cv.imshow('frame',gray)
    if cv.waitKey(1)==ord('q')
        break

cap.release()
cv.destroyAllWindows()

# %% [markdown]
# ## 读取本地视频

# %%
import numpy as np
import cv2  as cv

cap=cv.VideoCapture("vtest.avi")
while  cap.isOpened():
    ret,frame=cap.read()
    if not ret:
        print("Can't receive fram  exiting....")
        break
    gray=cv.cvtColor(frame,cv.COLOR_BGR2GRAY)
    
    cv.imshow('frame',gray)

    if cv.waitKey(1)==ord('q'):
        break
#释放
cap.release()
cv.destroyAllWindows()

# %% [markdown]
# ## 保存视频

# %%
import numpy as np
import cv2 as cv
cap = cv.VideoCapture(0)
# Define the codec and create VideoWriter object
fourcc = cv.VideoWriter_fourcc(*'XVID')  #视频编码格式
out = cv.VideoWriter('output.avi', fourcc, 20.0, (640,  480))
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    frame = cv.flip(frame, 0)
    # write the flipped frame
    out.write(frame)
    cv.imshow('frame', frame)
    if cv.waitKey(1) == ord('q'):
        break
# Release everything if job is finished
cap.release()
out.release()
cv.destroyAllWindows()

# %% [markdown]
# ## Drawing Functions in OpenCV

# %%
import numpy as np
import cv2 as cv

# Create a black image
img=np.zeros((512,512,3),np.uint8)
cv.line(img,(0,0),(511,511),(255,0,0),5) #line
cv.rectangle (img,(384,0),(510,128),(0,255,0),3)
cv.circle (img,(447,63), 63, (0,0,255), -1)
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,'OpenCV',(10,500), font, 4,(255,255,255),2,cv.LINE_AA)
cv.imshow('',img)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Mouse as a Paint-Brush

# %%
import cv2 as cv
events=[i for i in dir(cv) if 'EVENT' in i]
print(events)
# Out:
# ['EVENT_FLAG_ALTKEY', 'EVENT_FLAG_CTRLKEY', 'EVENT_FLAG_LBUTTON', 'EVENT_FLAG_MBUTTON', 'EVENT_FLAG_RBUTTON', 'EVENT_FLAG_SHIFTKEY', 'EVENT_LBUTTONDBLCLK', 'EVENT_LBUTTONDOWN', 'EVENT_LBUTTONUP', 'EVENT_MBUTTONDBLCLK', 'EVENT_MBUTTONDOWN', 'EVENT_MBUTTONUP', 'EVENT_MOUSEHWHEEL', 'EVENT_MOUSEMOVE', 'EVENT_MOUSEWHEEL', 'EVENT_RBUTTONDBLCLK', 'EVENT_RBUTTONDOWN', 'EVENT_RBUTTONUP']

# %%
import numpy as np
import cv2 as  cv

def draw_circle(event,x,y,flags,param):
    if event == cv.EVENT_LBUTTONDBLCLK:
        cv.circle(img,(x,y),100,(255,0,0),-1)
    
# Create a black image, a window and bind the function to window

img=np.zeros((512,512,3),np.uint8)
cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle)

while(1):
    cv.imshow('image',img)
    if cv.waitKey(20)&0xff==27:
        break

cv.destroyAllWindows()

# %% [markdown]
# ## 通过鼠标事件 进行不同的动作

# %%
import numpy as np
import cv2 as cv
drawing = False # true if mouse is pressed
mode = True # if True, draw rectangle. Press 'm' to toggle to curve
ix,iy = -1,-1
# mouse callback function
def draw_circle2(event,x,y,flags,param):
    global ix,iy,drawing,mode
    if event == cv.EVENT_LBUTTONDOWN:
        drawing = True
        ix,iy = x,y
    elif event == cv.EVENT_MOUSEMOVE:
        if drawing == True:
            if mode == True:
                cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
            else:
                cv.circle(img,(x,y),5,(0,0,255),-1)
    elif event == cv.EVENT_LBUTTONUP:
        drawing = False
        if mode == True:
            cv.rectangle(img,(ix,iy),(x,y),(0,255,0),-1)
        else:
            cv.circle(img,(x,y),5,(0,0,255),-1)

img = np.zeros((512,512,3), np.uint8)
cv.namedWindow('image')
cv.setMouseCallback('image',draw_circle2)
while(1):
    cv.imshow('image',img)
    k = cv.waitKey(1) & 0xFF
    if k == ord('m'):
        mode = not mode
    elif k == 27:
        break
cv.destroyAllWindows()

# %% [markdown]
# ## 轨迹栏为调色板

# %%
import numpy as np
import cv2 as cv

def  nothing(x):
    pass

# Create a black imge a window
img = np.zeros((300,512,3),np.uint8)
cv.namedWindow('image')

# create trackbars for color change
cv.createTrackbar('R','image',0,255,nothing)
cv.createTrackbar('G','image',0,255,nothing)
cv.createTrackbar('B','image',0,255,nothing)

# create switch for ON/OFF functionality
cv.createTrackbar('0 : OFF \n1 : ON', 'image',0,1,nothing)

while(1):
    cv.imshow('image',img)
    k=cv.waitKey(1)&0xff
    if k==27:
        break
    # get  current positions of four trackbars
    r=cv.getTrackbarPos('R','image')
    g=cv.getTrackbarPos('G','image')
    b=cv.getTrackbarPos('B','image')
    s=cv.getTrackbarPos('0 : OFF \n1 : ON', 'image')

    if s== 0:
        img[:]=0
    else:
        img[:]=[b,g,r]

cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# e:\QWH\NO.1 科目分类\NO.3 机器人\NO.1 机器视觉\NO.2 实现教程\NO.1 OPENCV\NO.1 教程\官方教程\学习案例\Class2_opencv中的GUI功能\class2.ipynb Cell 17 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/e%3A/QWH/NO.1%20%E7%A7%91%E7%9B%AE%E5%88%86%E7%B1%BB/NO.3%20%E6%9C%BA%E5%99%A8%E4%BA%BA/NO.1%20%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89/NO.2%20%E5%AE%9E%E7%8E%B0%E6%95%99%E7%A8%8B/NO.1%20OPENCV/NO.1%20%E6%95%99%E7%A8%8B/%E5%AE%98%E6%96%B9%E6%95%99%E7%A8%8B/%E5%AD%A6%E4%B9%A0%E6%A1%88%E4%BE%8B/Class2_opencv%E4%B8%AD%E7%9A%84GUI%E5%8A%9F%E8%83%BD/class2.ipynb#X24sZmlsZQ%3D%3D?line=22'>23</a>     break
#      <a href='vscode-notebook-cell:/e%3A/QWH/NO.1%20%E7%A7%91%E7%9B%AE%E5%88%86%E7%B1%BB/NO.3%20%E6%9C%BA%E5%99%A8%E4%BA%BA/NO.1%20%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89/NO.2%20%E5%AE%9E%E7%8E%B0%E6%95%99%E7%A8%8B/NO.1%20OPENCV/NO.1%20%E6%95%99%E7%A8%8B/%E5%AE%98%E6%96%B9%E6%95%99%E7%A8%8B/%E5%AD%A6%E4%B9%A0%E6%A1%88%E4%BE%8B/Class2_opencv%E4%B8%AD%E7%9A%84GUI%E5%8A%9F%E8%83%BD/class2.ipynb#X24sZmlsZQ%3D%3D?line=23'>24</a> # get  current positions of four trackbars
# ---> <a href='vscode-notebook-cell:/e%3A/QWH/NO.1%20%E7%A7%91%E7%9B%AE%E5%88%86%E7%B1%BB/NO.3%20%E6%9C%BA%E5%99%A8%E4%BA%BA/NO.1%20%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89/NO.2%20%E5%AE%9E%E7%8E%B0%E6%95%99%E7%A8%8B/NO.1%20OPENCV/NO.1%20%E6%95%99%E7%A8%8B/%E5%AE%98%E6%96%B9%E6%95%99%E7%A8%8B/%E5%AD%A6%E4%B9%A0%E6%A1%88%E4%BE%8B/Class2_opencv%E4%B8%AD%E7%9A%84GUI%E5%8A%9F%E8%83%BD/class2.ipynb#X24sZmlsZQ%3D%3D?line=24'>25</a> r=cv.getTrackbarPos('R','image')
#      <a href='vscode-notebook-cell:/e%3A/QWH/NO.1%20%E7%A7%91%E7%9B%AE%E5%88%86%E7%B1%BB/NO.3%20%E6%9C%BA%E5%99%A8%E4%BA%BA/NO.1%20%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89/NO.2%20%E5%AE%9E%E7%8E%B0%E6%95%99%E7%A8%8B/NO.1%20OPENCV/NO.1%20%E6%95%99%E7%A8%8B/%E5%AE%98%E6%96%B9%E6%95%99%E7%A8%8B/%E5%AD%A6%E4%B9%A0%E6%A1%88%E4%BE%8B/Class2_opencv%E4%B8%AD%E7%9A%84GUI%E5%8A%9F%E8%83%BD/class2.ipynb#X24sZmlsZQ%3D%3D?line=25'>26</a> g=cv.getTrackbarPos('G','image')
#      <a href='vscode-notebook-cell:/e%3A/QWH/NO.1%20%E7%A7%91%E7%9B%AE%E5%88%86%E7%B1%BB/NO.3%20%E6%9C%BA%E5%99%A8%E4%BA%BA/NO.1%20%E6%9C%BA%E5%99%A8%E8%A7%86%E8%A7%89/NO.2%20%E5%AE%9E%E7%8E%B0%E6%95%99%E7%A8%8B/NO.1%20OPENCV/NO.1%20%E6%95%99%E7%A8%8B/%E5%AE%98%E6%96%B9%E6%95%99%E7%A8%8B/%E5%AD%A6%E4%B9%A0%E6%A1%88%E4%BE%8B/Class2_opencv%E4%B8%AD%E7%9A%84GUI%E5%8A%9F%E8%83%BD/class2.ipynb#X24sZmlsZQ%3D%3D?line=26'>27</a> b=cv.getTrackbarPos('B','image')
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window_w32.cpp:2581: error: (-27:Null pointer) NULL window: 'image' in function 'cvGetTrackbarPos'

# %%
import numpy as np
import cv2 as cv

img=np.ones((300,512,3),np.uint8)
cv.imshow('image',img)
while True:
    k=cv.waitKey(1)&0xff
    print(k)
    if k == ord('q'):
        break
    
cv.destroyAllWindows()
# Out:
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 97
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 100
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 100
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 255
# 113
